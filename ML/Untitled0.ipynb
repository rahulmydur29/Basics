# %%
# !wget https://archive.ics.uci.edu/ml/datasets/Heart+Disease
# Out:
# --2022-05-29 05:40:47--  https://archive.ics.uci.edu/ml/datasets/Heart+Disease
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Heart+Disease’
#
# Heart+Disease           [ <=>                ]  53.61K  --.-KB/s    in 0.1s
#
# 2022-05-29 05:40:47 (418 KB/s) - ‘Heart+Disease’ saved [54901]
