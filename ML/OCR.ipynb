# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# !pip install pytesseract --quiet

# %%
# !wget https://png.pngtree.com/png-vector/20210131/ourmid/pngtree-inspirational-quotes-t-shirt-design-svg-png-failure-is-success-in-png-image_2878769.jpg -O quote.png
# Out:
# --2022-03-22 07:32:24--  https://png.pngtree.com/png-vector/20210131/ourmid/pngtree-inspirational-quotes-t-shirt-design-svg-png-failure-is-success-in-png-image_2878769.jpg
# Resolving png.pngtree.com (png.pngtree.com)... 104.18.3.157, 104.18.2.157, 2606:4700::6812:29d, ...
# Connecting to png.pngtree.com (png.pngtree.com)|104.18.3.157|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13329 (13K) [image/jpg]
# Saving to: ‘quote.png’
#
# quote.png           100%[===================>]  13.02K  --.-KB/s    in 0s
#
# 2022-03-22 07:32:24 (71.5 MB/s) - ‘quote.png’ saved [13329/13329]

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread("/content/quote.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=360x360 at 0x7F7012BE6FD0>

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# !pip install pytesseract --quiet

# %%
import pytesseract as pt
op=pt.image_to_string(img)
print(op)
# Out:
# Fai
# ‘Sa
# eP
